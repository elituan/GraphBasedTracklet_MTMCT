# %%
import pickle

# %%
path = "c041_dets.pkl"
path_feat = "c041_dets_feat.pkl"

# %%
with open(path, 'rb') as path_:
    det_dict = pickle.load(path_)

# %%
det_dict
# Out:
# {'img000000_000': {'bbox': (1145, 142, 1155, 150),
#   'frame': 'img000000',
#   'id': 0,
#   'imgname': 'img000000_000.png',
#   'class': 2,
#   'conf': 0.11151123046875},
#  'img000000_001': {'bbox': (1060, 125, 1084, 136),
#   'frame': 'img000000',
#   'id': 1,
#   'imgname': 'img000000_001.png',
#   'class': 2,
#   'conf': 0.1329345703125},
#  'img000000_002': {'bbox': (1132, 137, 1142, 146),
#   'frame': 'img000000',
#   'id': 2,
#   'imgname': 'img000000_002.png',
#   'class': 2,
#   'conf': 0.1356201171875},
#  'img000000_003': {'bbox': (1089, 136, 1113, 152),
#   'frame': 'img000000',
#   'id': 3,
#   'imgname': 'img000000_003.png',
#   'class': 2,
#   'conf': 0.414306640625},
#  'img000000_004': {'bbox': (959, 111, 1001, 135),
#   'frame': 'img000000',
#   'id': 4,
#   'imgname': 'img000000_004.png',
#   'class': 2,
#   'conf': 0.47216796875},
#  'img000000_005': {'bbox': (940, 104, 972, 122),
#   'frame': 'img000000',
#   'id': 5,
#   'imgname': 'img000000_005.png',
# ...
