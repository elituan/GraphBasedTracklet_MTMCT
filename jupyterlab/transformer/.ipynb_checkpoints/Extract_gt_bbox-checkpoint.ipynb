# %%
from pathlib import Path
import cv2
from tqdm import tqdm
import pickle
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## get gt path

# %%
data_path = "/home/eli/coding/reid_all/AIC21-MTMC/datasets/AIC21_Track3_MTMC_Tracking/"
chosen_dirs = ['train','validation']
p = Path(data_path)
# sce_path = [x for x in p.iterdir() if x.is_dir()]
gts = []
for chosen_dir in chosen_dirs:
    gts.extend(list(sorted(p.glob(f'{chosen_dir}/*/*/gt/gt.txt'))))
gts[-1]
# Out:
# PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/datasets/AIC21_Track3_MTMC_Tracking/validation/S05/c036/gt/gt.txt')

# %%
def get_gt_mot(gt, mots):
    # Prepare for extract MOT infor
    lines = [line.split(',') for line in gt.read_text().split("\n")][:-1]
    oid_unique = list(sorted(set([line[1] for line in lines])))
    line_chunks = []
    for oid in oid_unique:
        tmp = [line for line in lines if line[1]==oid]
        line_chunks.append(tmp)
    camId = gt.parent.parent.name
    sceId = gt.parent.parent.parent.name
    dirId = gt.parent.parent.parent.parent.name

    for _, line_chunk in enumerate(line_chunks):
        tracklet = {}
        frame_list = []
        for bboxID,line in enumerate(line_chunk):
            # extract information for mots dic
            frameId,oid,t,l,w,h,_,_,_,_ = line
            frame = "img%06d" % (int(frameId)-1,)
            frame_list.append(int(frameId)-1)
            tid = "tid%03d" % (int(oid),)
            bboxid_ = "bbid%03d" % (bboxID,)
            tracklet[bboxID]= {'bbox': (int(t),int(l),int(w),int(h)),
                               'frame' : frame,
                               'tid': oid,
                               'imgname': '{}_{}_{}_{}.jpg'.format(tid, camId,1,bboxid_) 
                              }
            
        dir_sid_cam_tid = (dirId,sceId,camId,oid)
        mots[dir_sid_cam_tid] = {
                    'dirId':dirId,
                    'sceId':sceId,
                    'cam': camId,
                   'tid': oid,
                   'frame_list': frame_list,
                    'tracklet': tracklet
                   }
    return mots

mots = dict()
for gt in gts:
    mots = get_gt_mot(gt, mots)
len(mots)
# Out:
# 3037

# %%
from sklearn.model_selection import train_test_split
# train test split
mot_key = list(mots.keys())
mot_key_train, mot_key_test, y_train, y_test = train_test_split(mot_key, mot_key, test_size=0.1, random_state=21)
len(mot_key_train)
# Out:
# 2733

# %%
# Prepare for saving image
src_path = Path('/home/eli/coding/reid_all/AIC21-MTMC/datasets/detection/images') 
dst_train_path = Path('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_train')
if not dst_train_path.exists(): 
    dst_train_path.mkdir(parents=True, exist_ok=True)
dst_test_path = Path('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test')
if not dst_test_path.exists(): 
    dst_test_path.mkdir(parents=True, exist_ok=True)
dst_query_path = Path('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_query')
if not dst_query_path.exists(): 
    dst_query_path.mkdir(parents=True, exist_ok=True)

## Save image of bbox
train_paths = []
test_paths =[]
for mot_key in tqdm(mot_key_test):
    tracklet = mots[mot_key]['tracklet']
    dirId = mots[mot_key]['dirId']
    sceId = mots[mot_key]['sceId']
    cam = mots[mot_key]['cam']

    if cam != 'c001': continue
        
    test_bbox_paths =[]
    for _,bbox in tracklet.items():
        frame, tlwh, imgname = bbox['frame'], bbox['bbox'], bbox['imgname']
        t,l,w,h = tlwh
        img_frame_path = src_path.joinpath(dirId,sceId,cam,'img1',frame+'.jpg')
        img_frame = cv2.imread(str(img_frame_path))
        dst_img_path = dst_test_path.joinpath(imgname)
#         print (img_frame_path)
        cv2.imwrite(str(dst_img_path), img_frame[l:l+h, t:t+w])
        test_bbox_paths.append([dst_img_path, tlwh])
    test_paths.append(test_bbox_paths)

for mot_key in tqdm(mot_key_train):
    tracklet = mots[mot_key]['tracklet']
    dirId = mots[mot_key]['dirId']
    sceId = mots[mot_key]['sceId']
    cam = mots[mot_key]['cam']

    if cam != 'c001': continue
    
    train_bbox_paths = []
    for _,bbox in tracklet.items(): 
        frame, tlwh, imgname = bbox['frame'], bbox['bbox'], bbox['imgname']
        t,l,w,h = tlwh
        img_frame_path = src_path.joinpath(dirId,sceId,cam,'img1',frame+'.jpg')
        img_frame = cv2.imread(str(img_frame_path))
        dst_img_path = dst_train_path.joinpath(imgname)
#         print (img_frame_path)
        cv2.imwrite(str(dst_img_path), img_frame[l:l+h, t:t+w])
        train_bbox_paths.append([dst_img_path, tlwh])
    train_paths.append(train_bbox_paths)
# Out:
# 100%|██████████| 304/304 [00:08<00:00, 37.05it/s]
# 100%|██████████| 2733/2733 [01:16<00:00, 35.78it/s]

# %%
# Save pickle
datatrain_pickle_path = Path('../reid/TransReID/data/aic21/datatrain.pickle')
train_test_paths = {
    'train_paths' : train_paths,
    'test_paths' : test_paths
}

pickle.dump(train_test_paths, datatrain_pickle_path.open('wb'))

# %%
tmp = pickle.load(datatrain_pickle_path.open('rb'))
tmp['test_paths']
# Out:
# [[[PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid000.jpg'),
#    (825, 272, 115, 100)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid001.jpg'),
#    (822, 273, 116, 100)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid002.jpg'),
#    (819, 274, 118, 100)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid003.jpg'),
#    (816, 275, 119, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid004.jpg'),
#    (814, 276, 120, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid005.jpg'),
#    (811, 277, 122, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid006.jpg'),
#    (808, 278, 123, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid007.jpg'),
#    (805, 280, 125, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid008.jpg'),
#    (802, 281, 126, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid009.jpg'),
#    (799, 282, 127, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid010.jpg'),
#    (796, 283, 129, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid011.jpg'),
#    (794, 284, 130, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid012.jpg'),
#    (791, 285, 131, 97)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid013.jpg'),
#    (788, 286, 133, 97)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid014.jpg'),
#    (785, 287, 134, 97)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid015.jpg'),
#    (776, 286, 139, 103)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid016.jpg'),
#    (775, 284, 139, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid017.jpg'),
#    (771, 285, 141, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid018.jpg'),
#    (768, 284, 140, 108)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid019.jpg'),
#    (765, 286, 142, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid020.jpg'),
#    (762, 286, 144, 109)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid021.jpg'),
#    (761, 289, 144, 108)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid022.jpg'),
#    (759, 291, 144, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid023.jpg'),
#    (754, 292, 146, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid024.jpg'),
#    (748, 293, 149, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid025.jpg'),
#    (745, 293, 151, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid026.jpg'),
#    (742, 293, 153, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid027.jpg'),
#    (739, 293, 155, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid028.jpg'),
#    (736, 295, 158, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid029.jpg'),
#    (730, 291, 156, 118)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid030.jpg'),
#    (728, 291, 156, 117)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid031.jpg'),
#    (726, 292, 155, 117)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid032.jpg'),
#    (723, 292, 156, 118)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid033.jpg'),
#    (720, 292, 158, 119)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid034.jpg'),
#    (717, 293, 160, 118)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid035.jpg'),
#    (715, 293, 158, 119)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid036.jpg'),
#    (708, 302, 158, 113)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid037.jpg'),
#    (704, 302, 163, 113)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid038.jpg'),
#    (700, 302, 164, 113)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid039.jpg'),
#    (696, 303, 167, 112)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid040.jpg'),
#    (695, 303, 167, 113)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid041.jpg'),
#    (694, 302, 167, 113)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid042.jpg'),
#    (687, 300, 167, 122)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid043.jpg'),
#    (685, 301, 168, 122)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid044.jpg'),
#    (684, 301, 168, 122)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid045.jpg'),
#    (683, 303, 166, 121)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid046.jpg'),
#    (681, 303, 166, 121)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid047.jpg'),
#    (679, 303, 166, 121)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid048.jpg'),
#    (674, 305, 169, 120)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid049.jpg'),
#    (669, 306, 175, 120)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid050.jpg'),
#    (665, 307, 178, 120)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid051.jpg'),
#    (662, 307, 179, 121)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid052.jpg'),
#    (660, 308, 179, 120)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid053.jpg'),
#    (658, 308, 178, 120)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid054.jpg'),
#    (655, 309, 180, 118)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid055.jpg'),
#    (653, 309, 183, 118)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid056.jpg'),
#    (636, 306, 190, 124)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid057.jpg'),
#    (634, 307, 193, 124)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid058.jpg'),
#    (631, 308, 195, 123)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid059.jpg'),
#    (628, 309, 194, 122)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid060.jpg'),
#    (623, 310, 191, 122)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid061.jpg'),
#    (618, 310, 194, 123)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid062.jpg'),
#    (612, 310, 200, 124)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid063.jpg'),
#    (606, 310, 207, 124)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid064.jpg'),
#    (596, 313, 199, 129)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid065.jpg'),
#    (587, 314, 211, 128)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid066.jpg'),
#    (575, 314, 224, 130)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid067.jpg'),
#    (562, 314, 234, 133)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid068.jpg'),
#    (551, 314, 243, 136)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid069.jpg'),
#    (540, 319, 235, 133)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid070.jpg'),
#    (524, 321, 259, 132)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid071.jpg'),
#    (510, 322, 268, 131)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid072.jpg'),
#    (502, 322, 268, 131)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid073.jpg'),
#    (491, 323, 256, 132)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid074.jpg'),
#    (472, 328, 276, 132)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid075.jpg'),
#    (461, 329, 279, 130)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid076.jpg'),
#    (438, 328, 284, 134)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid077.jpg'),
#    (424, 330, 292, 132)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid078.jpg'),
#    (392, 328, 317, 142)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid079.jpg'),
#    (378, 335, 318, 129)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid080.jpg'),
#    (352, 334, 348, 135)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid081.jpg'),
#    (327, 337, 344, 129)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid082.jpg'),
#    (298, 338, 358, 130)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid083.jpg'),
#    (284, 339, 347, 129)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid084.jpg'),
#    (260, 340, 336, 133)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid085.jpg'),
#    (230, 339, 350, 133)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid086.jpg'),
#    (210, 342, 352, 130)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid087.jpg'),
#    (172, 341, 359, 134)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid088.jpg'),
#    (150, 344, 364, 131)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid089.jpg'),
#    (125, 345, 380, 132)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid090.jpg'),
#    (91, 345, 365, 135)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid091.jpg'),
#    (73, 347, 361, 130)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid092.jpg'),
#    (25, 348, 363, 134)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid093.jpg'),
#    (15, 350, 345, 132)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid094.jpg'),
#    (0, 350, 342, 133)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid095.jpg'),
#    (0, 351, 304, 140)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid042_c001_1_bbid096.jpg'),
#    (0, 352, 265, 146)]],
#  [[PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid000.jpg'),
#    (1557, 336, 363, 169)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid001.jpg'),
#    (1487, 337, 432, 162)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid002.jpg'),
#    (1413, 339, 449, 162)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid003.jpg'),
#    (1340, 340, 466, 163)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid004.jpg'),
#    (1266, 342, 483, 163)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid005.jpg'),
#    (1183, 340, 474, 165)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid006.jpg'),
#    (1099, 339, 466, 166)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid007.jpg'),
#    (1016, 337, 457, 168)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid008.jpg'),
#    (926, 338, 458, 168)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid009.jpg'),
#    (835, 339, 460, 168)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid010.jpg'),
#    (745, 340, 461, 168)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid011.jpg'),
#    (654, 341, 462, 168)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid012.jpg'),
#    (553, 344, 472, 167)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid013.jpg'),
#    (452, 347, 481, 166)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid014.jpg'),
#    (351, 350, 491, 165)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid015.jpg'),
#    (250, 353, 500, 164)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid016.jpg'),
#    (149, 356, 510, 163)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid017.jpg'),
#    (75, 359, 467, 165)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid093_c001_1_bbid018.jpg'),
#    (0, 362, 423, 167)]],
#  [[PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid000.jpg'),
#    (1670, 420, 250, 172)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid001.jpg'),
#    (1643, 415, 277, 164)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid002.jpg'),
#    (1591, 405, 327, 161)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid003.jpg'),
#    (1565, 397, 338, 155)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid004.jpg'),
#    (1540, 386, 325, 154)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid005.jpg'),
#    (1514, 374, 311, 153)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid006.jpg'),
#    (1496, 366, 305, 150)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid007.jpg'),
#    (1468, 366, 279, 142)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid008.jpg'),
#    (1444, 346, 284, 158)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid009.jpg'),
#    (1434, 354, 262, 135)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid010.jpg'),
#    (1414, 348, 242, 135)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid011.jpg'),
#    (1412, 343, 227, 132)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid012.jpg'),
#    (1387, 340, 216, 124)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid013.jpg'),
#    (1362, 335, 209, 123)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid014.jpg'),
#    (1354, 333, 201, 111)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid015.jpg'),
#    (1328, 328, 196, 116)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid016.jpg'),
#    (1319, 325, 194, 114)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid017.jpg'),
#    (1298, 322, 188, 108)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid018.jpg'),
#    (1292, 318, 183, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid019.jpg'),
#    (1272, 316, 169, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid020.jpg'),
#    (1262, 313, 171, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid021.jpg'),
#    (1258, 311, 161, 103)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid022.jpg'),
#    (1243, 307, 155, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid023.jpg'),
#    (1235, 305, 147, 103)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid024.jpg'),
#    (1226, 304, 145, 97)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid025.jpg'),
#    (1210, 304, 147, 91)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid026.jpg'),
#    (1207, 302, 138, 89)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid027.jpg'),
#    (1199, 300, 135, 88)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid028.jpg'),
#    (1190, 297, 133, 87)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid029.jpg'),
#    (1182, 295, 130, 86)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid030.jpg'),
#    (1173, 292, 128, 86)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid031.jpg'),
#    (1165, 290, 125, 85)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid032.jpg'),
#    (1156, 287, 123, 84)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid033.jpg'),
#    (1148, 285, 120, 83)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid034.jpg'),
#    (1146, 284, 116, 79)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid035.jpg'),
#    (1143, 283, 109, 78)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid036.jpg'),
#    (1138, 281, 103, 75)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid037.jpg'),
#    (1134, 279, 97, 71)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid038.jpg'),
#    (1129, 277, 91, 68)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid039.jpg'),
#    (1125, 275, 90, 68)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid040.jpg'),
#    (1120, 274, 89, 67)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid041.jpg'),
#    (1116, 272, 88, 67)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid042.jpg'),
#    (1111, 271, 87, 66)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid043.jpg'),
#    (1107, 269, 85, 66)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid044.jpg'),
#    (1102, 267, 84, 65)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid045.jpg'),
#    (1098, 266, 83, 65)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid052_c001_1_bbid046.jpg'),
#    (1093, 264, 82, 64)]],
#  [[PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid000.jpg'),
#    (889, 235, 70, 65)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid001.jpg'),
#    (887, 235, 71, 66)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid002.jpg'),
#    (884, 235, 73, 67)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid003.jpg'),
#    (882, 235, 74, 68)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid004.jpg'),
#    (880, 236, 75, 68)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid005.jpg'),
#    (878, 236, 76, 69)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid006.jpg'),
#    (875, 236, 78, 70)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid007.jpg'),
#    (873, 236, 79, 71)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid008.jpg'),
#    (872, 238, 78, 71)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid009.jpg'),
#    (872, 241, 78, 70)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid010.jpg'),
#    (871, 243, 77, 70)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid011.jpg'),
#    (870, 245, 76, 69)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid012.jpg'),
#    (870, 248, 76, 69)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid013.jpg'),
#    (869, 250, 75, 68)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid014.jpg'),
#    (868, 249, 76, 72)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid015.jpg'),
#    (867, 250, 76, 72)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid016.jpg'),
#    (866, 250, 77, 73)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid017.jpg'),
#    (865, 250, 77, 75)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid018.jpg'),
#    (864, 249, 79, 77)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid019.jpg'),
#    (863, 250, 80, 77)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid020.jpg'),
#    (861, 252, 83, 76)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid021.jpg'),
#    (861, 253, 85, 76)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid022.jpg'),
#    (860, 254, 86, 77)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid023.jpg'),
#    (860, 256, 88, 77)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid024.jpg'),
#    (859, 257, 90, 77)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid025.jpg'),
#    (859, 258, 91, 78)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid026.jpg'),
#    (858, 259, 93, 78)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid027.jpg'),
#    (858, 260, 95, 78)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid028.jpg'),
#    (857, 261, 96, 79)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid029.jpg'),
#    (857, 263, 98, 79)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid030.jpg'),
#    (856, 264, 100, 79)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid031.jpg'),
#    (856, 265, 101, 80)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid032.jpg'),
#    (855, 266, 103, 80)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid033.jpg'),
#    (854, 267, 106, 81)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid034.jpg'),
#    (855, 267, 105, 84)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid035.jpg'),
#    (857, 269, 103, 87)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid036.jpg'),
#    (857, 269, 104, 89)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid037.jpg'),
#    (856, 269, 105, 91)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid038.jpg'),
#    (855, 268, 106, 95)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid039.jpg'),
#    (853, 267, 107, 97)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid040.jpg'),
#    (852, 266, 107, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid041.jpg'),
#    (848, 269, 112, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid042.jpg'),
#    (845, 270, 113, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid043.jpg'),
#    (842, 272, 116, 103)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid044.jpg'),
#    (839, 274, 117, 102)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid045.jpg'),
#    (835, 275, 119, 103)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid046.jpg'),
#    (831, 276, 122, 106)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid047.jpg'),
#    (828, 274, 122, 111)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid048.jpg'),
#    (813, 277, 136, 111)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid049.jpg'),
#    (805, 279, 145, 110)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid050.jpg'),
#    (797, 281, 150, 112)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid051.jpg'),
#    (786, 282, 158, 116)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid052.jpg'),
#    (778, 283, 161, 117)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid053.jpg'),
#    (762, 283, 164, 125)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid054.jpg'),
#    (753, 284, 171, 124)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid055.jpg'),
#    (739, 285, 182, 125)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid056.jpg'),
#    (730, 288, 185, 121)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid057.jpg'),
#    (707, 294, 197, 120)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid058.jpg'),
#    (684, 300, 209, 119)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid059.jpg'),
#    (661, 300, 221, 122)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid060.jpg'),
#    (637, 300, 233, 125)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid061.jpg'),
#    (614, 300, 244, 128)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid062.jpg'),
#    (590, 300, 254, 131)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid063.jpg'),
#    (568, 303, 259, 130)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid064.jpg'),
#    (545, 306, 263, 129)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid065.jpg'),
#    (508, 308, 279, 131)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid066.jpg'),
#    (471, 311, 294, 134)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid067.jpg'),
#    (434, 313, 310, 136)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid068.jpg'),
#    (397, 315, 325, 138)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid069.jpg'),
#    (371, 312, 338, 141)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid070.jpg'),
#    (320, 318, 342, 138)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid071.jpg'),
#    (278, 321, 350, 138)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid072.jpg'),
#    (235, 325, 358, 137)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid073.jpg'),
#    (193, 328, 366, 137)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid074.jpg'),
#    (150, 331, 374, 136)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid075.jpg'),
#    (112, 333, 374, 136)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid076.jpg'),
#    (74, 334, 374, 135)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid077.jpg'),
#    (37, 337, 363, 139)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid078.jpg'),
#    (0, 340, 352, 143)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid086_c001_1_bbid079.jpg'),
#    (0, 341, 308, 136)]],
#  [[PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid000.jpg'),
#    (847, 267, 94, 84)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid001.jpg'),
#    (849, 268, 96, 81)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid002.jpg'),
#    (851, 269, 98, 78)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid003.jpg'),
#    (852, 270, 99, 79)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid004.jpg'),
#    (851, 270, 100, 81)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid005.jpg'),
#    (850, 272, 102, 86)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid006.jpg'),
#    (851, 273, 102, 85)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid007.jpg'),
#    (853, 273, 101, 86)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid008.jpg'),
#    (850, 283, 109, 80)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid009.jpg'),
#    (849, 273, 112, 96)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid010.jpg'),
#    (851, 274, 112, 96)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid011.jpg'),
#    (852, 274, 113, 97)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid012.jpg'),
#    (853, 275, 112, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid013.jpg'),
#    (855, 276, 112, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid014.jpg'),
#    (858, 277, 111, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid015.jpg'),
#    (860, 279, 111, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid016.jpg'),
#    (863, 280, 110, 98)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid017.jpg'),
#    (863, 281, 110, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid018.jpg'),
#    (865, 283, 110, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid019.jpg'),
#    (864, 283, 112, 101)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid020.jpg'),
#    (867, 291, 116, 99)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid021.jpg'),
#    (867, 290, 117, 103)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid022.jpg'),
#    (868, 292, 118, 105)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid023.jpg'),
#    (869, 292, 119, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid024.jpg'),
#    (872, 293, 118, 107)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid025.jpg'),
#    (873, 291, 123, 110)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid026.jpg'),
#    (873, 292, 130, 109)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid027.jpg'),
#    (873, 293, 136, 108)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid028.jpg'),
#    (883, 307, 129, 111)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid029.jpg'),
#    (887, 307, 129, 112)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid030.jpg'),
#    (891, 309, 130, 113)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid031.jpg'),
#    (893, 310, 129, 117)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid032.jpg'),
#    (893, 310, 143, 123)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid033.jpg'),
#    (893, 311, 147, 125)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid034.jpg'),
#    (896, 314, 153, 123)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid035.jpg'),
#    (899, 316, 157, 124)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid036.jpg'),
#    (905, 318, 157, 127)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid037.jpg'),
#    (908, 320, 157, 129)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid038.jpg'),
#    (917, 322, 167, 129)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid039.jpg'),
#    (917, 326, 174, 147)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid040.jpg'),
#    (920, 330, 180, 147)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid041.jpg'),
#    (925, 335, 184, 151)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid042.jpg'),
#    (929, 339, 189, 152)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid043.jpg'),
#    (942, 340, 201, 163)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid044.jpg'),
#    (950, 347, 207, 176)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid045.jpg'),
#    (953, 349, 215, 176)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid046.jpg'),
#    (971, 353, 218, 185)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid047.jpg'),
#    (960, 353, 252, 200)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid048.jpg'),
#    (993, 353, 248, 207)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid049.jpg'),
#    (998, 376, 256, 201)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid050.jpg'),
#    (1009, 381, 268, 209)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid051.jpg'),
#    (1016, 388, 290, 221)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid052.jpg'),
#    (1041, 392, 304, 240)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid053.jpg'),
#    (1048, 400, 327, 251)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid054.jpg'),
#    (1051, 420, 365, 259)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid055.jpg'),
#    (1086, 423, 382, 283)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid056.jpg'),
#    (1102, 437, 393, 290)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid057.jpg'),
#    (1128, 456, 429, 306)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid058.jpg'),
#    (1154, 474, 465, 322)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid059.jpg'),
#    (1191, 488, 475, 342)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid060.jpg'),
#    (1251, 509, 515, 367)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid061.jpg'),
#    (1286, 539, 530, 366)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid062.jpg'),
#    (1336, 567, 552, 393)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid063.jpg'),
#    (1393, 596, 527, 417)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid031_c001_1_bbid064.jpg'),
#    (1450, 623, 470, 448)]],
#  [[PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid000.jpg'),
#    (1581, 346, 339, 158)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid001.jpg'),
#    (1509, 347, 411, 160)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid002.jpg'),
#    (1445, 345, 432, 157)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid003.jpg'),
#    (1378, 343, 433, 158)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid004.jpg'),
#    (1312, 344, 430, 157)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid005.jpg'),
#    (1247, 344, 428, 156)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid006.jpg'),
#    (1181, 345, 425, 156)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid007.jpg'),
#    (1116, 345, 423, 155)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid008.jpg'),
#    (1050, 346, 420, 154)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid009.jpg'),
#    (972, 347, 421, 154)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid010.jpg'),
#    (893, 348, 422, 154)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid011.jpg'),
#    (815, 349, 423, 154)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid012.jpg'),
#    (737, 349, 424, 153)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid013.jpg'),
#    (658, 350, 425, 153)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid014.jpg'),
#    (580, 351, 426, 153)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid015.jpg'),
#    (500, 353, 420, 154)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid016.jpg'),
#    (419, 354, 414, 156)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid017.jpg'),
#    (339, 356, 409, 157)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid018.jpg'),
#    (258, 357, 403, 159)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid019.jpg'),
#    (178, 359, 397, 160)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid020.jpg'),
#    (98, 362, 390, 159)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid021.jpg'),
#    (17, 364, 383, 158)],
#   [PosixPath('/home/eli/coding/reid_all/AIC21-MTMC/reid/TransReID/data/aic21/image_test/tid034_c001_1_bbid022.jpg'),
#    (0, 363, 318, 160)]]]

# %%
list(range(10))[4:6]
# Out:
# [4, 5]
